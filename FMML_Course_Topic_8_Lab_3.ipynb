# %% [markdown]
# <a href="https://colab.research.google.com/github/ShriAmogh/fmml_projects/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-13 14:22:38--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   142MB/s    in 0.5s
#
# 2024-04-13 14:22:39 (142 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3076 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2829 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 85  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 9  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 5851    1206.6457v1  This paper analyzes the problem of Gaussian pr...    cs
# 7312   1711.09091v1  The astonishing success of AlphaGo Zero\cite{S...    cs
# 38239   1409.2433v1  We study the complexity of approximating solut...    cs
# 22334  1602.04548v1  In this paper we study predictive pattern mini...  stat
# 6088   1607.00669v3  It is well-known that the precision of data, h...  stat
# ...             ...                                                ...   ...
# 22363  1603.06846v2  We propose new metrics on sets, ontologies, an...  stat
# 475    1704.06194v2  Relation detection is a core component for man...    cs
# 13398   1203.3847v1  Handwritten Numeral recognition plays a vital ...    cs
# 37869   1004.1341v1  The outcome of a functional genomics pipeline ...  stat
# 5724    1202.6001v2  We introduce a novel and efficient sampling al...  stat
#
#                                                    title  year  \
# 5851   Exponential Regret Bounds for Gaussian Process...  2012
# 7312            Demystifying AlphaGo Zero as AlphaGo GAN  2017
# 38239  Approximating solution structure of the Weight...  2014
# 22334  Safe Pattern Pruning: An Efficient Approach fo...  2016
# 6088   Understanding the Energy and Precision Require...  2016
# ...                                                  ...   ...
# 22363  New metrics for learning and inference on sets...  2016
# 475    Improved Neural Relation Detection for Knowled...  2017
# 13398  Handwritten digit Recognition using Support Ve...  2012
# 37869  Algebraic Comparison of Partial Lists in Bioin...  2010
# 5724   Efficiently Sampling Multiplicative Attribute ...  2012
#
#                                                 keywords
# 5851   [deterministic, observations, algorithm, algor...
# 7312   [astonishing, zerocitesilver, worldwide, discu...
# 38239  [complexity, approximating, structure, bijecti...
# 22334  [predictive, construct, predictive, predictive...
# 6088   [precision, hyperparameters, representations, ...
# ...                                                  ...
# 22363  [ontologies, functions, probabilistic, includi...
# 475    [detection, component, applications, including...
# 13398  [handwritten, recognition, automation, especia...
# 37869  [functional, relevance, modelling, biological,...
# 5724   [introduce, efficient, algorithm, multiplicati...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 5851     [deterministic, observations, algorithm, algor...
# 7312     [astonishing, zerocitesilver, worldwide, discu...
# 38239    [complexity, approximating, structure, bijecti...
# 22334    [predictive, construct, predictive, predictive...
# 6088     [precision, hyperparameters, representations, ...
#                                ...
# 5991     [beginnings, automatic, statistician, regressi...
# 21822    [suggestions, parametrized, distances, general...
# 12290    [designing, personalized, algorithms, desirabl...
# 12149    [association, investigate, relationships, nucl...
# 17072    [automatic, identification, discourse, relatio...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8658 words.
# Out of those 4594 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f0d1ecf8-9005-4127-89da-c9e65a59f7ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0d1ecf8-9005-4127-89da-c9e65a59f7ca")) {                    Plotly.newPlot(                        "f0d1ecf8-9005-4127-89da-c9e65a59f7ca",                        [{"x":["dimension","observations","algorithm","convergence","regularity","assumptions","complement","deterministic","objective","exponential","behaviour","asymptotically","according","observation","probability","decreases","approximate","demystifying","qualitative","generation","astonishing","excitement","discussion","worldwide","understood","structured","specially","agreement","additionally","bijective","partition","structure","alignment","arbitrarily","particular","significant","generalize","approximating","representing","positions","approximation","complexity","obtaining","polynomial","computing","screening","development","introduce","searching","efficient","advantage","predictive","demonstrate","corresponding","computational","efficiently","contribution","construct","guaranteed","representations","validated","limitations","important","stochastic","empirical","classifier","analytical","synthetic","consumption","quantized","opportunity","incurring","requirements","precision","understanding","precisions","hyperparameters","throughput","hyperparameter","classification","implementations","theoretic","hypothesis","dimensions","specifies","optimization","regression","hypotheses","generalizes","consistent","accommodate","constraint","multipliers","disparate","unexplored","dedicated","exploding","considering","subdivide","effective","decomposition","leverages","inherently","factorizations","experiments","properties","direction","fundamentally","computation","parallelization","independent","alternating","probabilistic","factorization","application","iterative","processing","constraints","multiplicative","incorporate","informatics","different","regularization","effectiveness","techniques","literature","nonlinear","sparseness","variation","separation","nonnegative","demonstrated","formulation","investigating","suggested","including","challenge","hyperspectral","estimation","framework","smoothness","extensions","functions","algorithms","representation","principal","dimensional","specified","component","comparison","distributions","posterior","continuous","prototype","inference","distribution","researchers","variational","efficiency","variables","maintains","expressive","parameters","hierarchical","introduction","algebraic","statistical","influential","unsupervised","principles","robustness","synthesized","estimator","covariance","asymptotic","sensitive","contaminated","generalized","quadratic","involving","influence","introduced","canonical","knowledge","characterize","correlation","intuitive","assumption","aggregated","instances","interested","exploratory","sentiment","comparisons","proportion","individual","proportions","differences","unrealistic","surprisingly"],"y":[65,75,781,114,11,71,19,36,173,47,23,9,115,61,168,20,122,4,57,140,4,1,27,6,27,114,14,23,71,3,23,334,47,15,292,213,51,19,79,25,120,226,35,48,123,10,124,316,24,407,95,59,543,131,307,162,62,96,27,234,36,53,353,138,142,162,20,133,27,10,11,6,46,79,176,0,13,10,11,545,33,42,61,42,6,303,131,34,46,85,15,95,10,9,7,14,4,66,2,270,51,24,9,0,610,219,63,13,154,11,123,17,165,31,249,89,295,164,17,66,5,729,78,197,393,120,64,6,53,32,5,111,80,24,35,255,161,13,191,542,17,54,216,578,375,30,170,34,96,160,120,37,108,19,204,173,67,55,168,129,16,37,240,109,27,20,149,13,137,29,98,13,19,23,16,73,4,62,28,47,58,157,20,345,49,76,36,68,11,107,26,4,40,47,8,125,3,54,6,23],"type":"bar"},{"x":["dimension","observations","algorithm","convergence","regular ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4594,), (4594, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.825

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Scaling</span> <span style=''>Analysis</span> <span style=''>of</span> <span style=''>Affinity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Propagation</span> <br/><br/><span style=''>We</span> <span style=''>analyze</span> <span style=''>and</span> <span style=''>exploit</span> <span style=''>some</span> <span style=''>scaling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Affinity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Propagation</span> <span style=''>(AP)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>proposed</span> <span style=''>by</span> <span style=''>Frey</span> <span style=''>and</span> <span style=''>Dueck</span> <span style=''>(2007)</span> <span style=''>First</span> <span style=''>we</span> <span style=''>observe</span> <span style=''>that</span> <span style=''>a</span> <span style=''>divide</span> <span style=''>and</span> <span style=''>conquer</span> <span style=''>strategy</span> <span style=''>used</span> <span style=''>on</span> <span style=''>a</span> <span style=''>large</span> <span style=''>data</span> <span style=''>set</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchically</span> <span style=''>reduces</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>cal</span> <span style=''>O(N2)</span> <span style=''>to</span> <span style=''>cal</span> <span style=''>O(N(h2)(h1))</span> <span style=''>for</span> <span style=''>a</span> <span style=''>data</span> <span style=''>set</span> <span style=''>of</span> <span style=''>size</span> <span style=''>N</span> <span style=''>and</span> <span style=''>a</span> <span style=''>depth</span> <span style=''>h</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style=''>strategy</span> <span style=''>For</span> <span style=''>a</span> <span style=''>data</span> <span style=''>set</span> <span style=''>embedded</span> <span style=''>in</span> <span style=''>a</span> <span style=''>d</span> <span style='background-color:rgba(255, 0, 0, 0.3609022556390977);'>dimensional</span> <span style=''>space</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>this</span> <span style=''>is</span> <span style=''>obtained</span> <span style=''>without</span> <span style=''>notably</span> <span style=''>damaging</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>precision</span> <span style=''>except</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3401015228426396);'>dimension</span> <span style=''>d2</span> <span style=''>In</span> <span style=''>fact</span> <span style=''>for</span> <span style=''>d</span> <span style=''>larger</span> <span style=''>than</span> <span style=''>2</span> <span style=''>the</span> <span style=''>relative</span> <span style=''>loss</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>precision</span> <span style=''>scales</span> <span style=''>like</span> <span style=''>N(2</span> <span style=''>d)(h1)d</span> <span style=''>Finally</span> <span style=''>under</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>we</span> <span style=''>observe</span> <span style=''>that</span> <span style=''>there</span> <span style=''>is</span> <span style=''>a</span> <span style=''>value</span> <span style=''>s</span> <span style=''>of</span> <span style=''>the</span> <span style=''>penalty</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coefficient</span> <span style=''>a</span> <span style=''>free</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style=''>GAN</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>networks</span> <span style=''>(GANs)</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implicitly</span> <span style=''>learn</span> <span style=''>rich</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>over</span> <span style=''>images</span> <span style=''>audio</span> <span style=''>and</span> <span style=''>data</span> <span style=''>which</span> <span style=''>are</span> <span style=''>hard</span> <span style=''>to</span> <span style=''>model</span> <span style=''>with</span> <span style=''>an</span> <span style=''>explicit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>and</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>with</span> <span style=''>GANs</span> <span style=''>Within</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>we</span> <span style=''>use</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hamiltonian</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>marginalize</span> <span style=''>the</span> <span style=''>weights</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generator</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminator</span> <span style=''>networks</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>approach</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>straightforward</span> <span style=''>and</span> <span style=''>obtains</span> <span style=''>good</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>without</span> <span style=''>any</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interventions</span> <span style=''>such</span> <span style=''>as</span> <span style=''>feature</span> <span style=''>matching</span> <span style=''>or</span> <span style=''>mini</span> <span style=''>batch</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discrimination</span> <span style=''>By</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploring</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>over</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generator</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style=''>GAN</span> <span style=''>avoids</span> <span style=''>mode</span> <span style=''>collapse</span> <span style=''>produces</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style=''>and</span> <span style=''>diverse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candi ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3604436229205175);'>Distribution</span> <span style=''>Specific</span> <span style=''>Hardness</span> <span style=''>of</span> <span style=''>Learning</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>Although</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>routinely</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successfully</span> <span style=''>trained</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>using</span> <span style=''>simple</span> <span style=''>gradient</span> <span style=''>based</span> <span style=''>methods</span> <span style=''>most</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style=''>results</span> <span style=''>are</span> <span style=''>negative</span> <span style=''>showing</span> <span style=''>that</span> <span style=''>learning</span> <span style=''>such</span> <span style=''>networks</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>in</span> <span style=''>a</span> <span style=''>worst</span> <span style=''>case</span> <span style=''>sense</span> <span style=''>over</span> <span style=''>all</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributions</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>take</span> <span style=''>a</span> <span style=''>more</span> <span style=''>nuanced</span> <span style=''>view</span> <span style=''>and</span> <span style=''>consider</span> <span style=''>whether</span> <span style=''>specific</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumptions</span> <span style=''>on</span> <span style=''>the</span> <span style=''>niceness</span> <span style=''>of</span> <span style=''>the</span> <span style=''>input</span> <span style='background-color:rgba(255, 0, 0, 0.3604436229205175);'>distribution</span> <span style=''>or</span> <span style=''>niceness</span> <span style=''>of</span> <span style=''>the</span> <span style=''>target</span> <span style=''>function</span> <span style=''>(eg</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3461538461538462);'>smoothness</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714285);'>degeneracy</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>incoherence</span> <span style=''>random</span> <span style=''>choice</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>etc)</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficient</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantee</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>learnability</span> <span style=''>using</span> <span style=''>gradient</span> <span style=''>based</span> <span style=''>methods</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>evidence</span> <span style=''>that</span> <span style=''>neither</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumptions</span> <span style=''>alone</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficient</span> <span style=''>On</span> <span style=''>the</span> <span style=''>one</span> <span style=''>hand</span> <span style=''>for</span> <span style=''>any</span> <span style=''>member</span> <span style=''>of</span> <span style=''>a</span> <span style=''>class</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Introducing</span> <span style=''>ReQuEST</span> <span style=''>an</span> <span style=''>Open</span> <span style=''>Platform</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reproducible</span> <span style=''>and</span> <span style=''>Quality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Efficient</span> <span style=''>Systems</span> <span style=''>ML</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Tournaments</span> <br/><br/><span style=''>Co</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>designing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>based</span> <span style=''>systems</span> <span style=''>across</span> <span style=''>the</span> <span style=''>whole</span> <span style=''>hardwaresoftware</span> <span style=''>stack</span> <span style=''>to</span> <span style=''>trade</span> <span style=''>off</span> <span style=''>speed</span> <span style=''>accuracy</span> <span style=''>energy</span> <span style=''>and</span> <span style=''>costs</span> <span style=''>is</span> <span style=''>becoming</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extremely</span> <span style=''>complex</span> <span style=''>and</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consuming</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Researchers</span> <span style=''>often</span> <span style=''>struggle</span> <span style=''>to</span> <span style=''>evaluate</span> <span style=''>and</span> <span style=''>compare</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>published</span> <span style=''>works</span> <span style=''>across</span> <span style=''>rapidly</span> <span style=''>evolving</span> <span style=''>software</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frameworks</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>heterogeneous</span> <span style=''>hardware</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>platforms</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compilers</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>libraries</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>models</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environments</span> <span style=''>We</span> <span style=''>present</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>community</span> <span style=''>effort</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>an</span> <span style=''>open</span> <span style=''>co</span> <span style=''>design</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tournament</span> <span style=''>platform</span> <span style=''>with</span> <span style=''>an</span> <span style=''>online</span> <span style=''>public</span> <span style=''>scoreboard</span> <span style=''>It</span> <span style=''>will</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>gradually</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporate</span> <span style=''>best</span> <span style=''>research</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practices</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style=''>a</span> <span style=''>common</span> <span style=''>way</span> <span style=''>for</span> <span style=''>multidisciplinary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>researchers</span> <span style=''>to</span> <span style=''>optimize</span> <span style=''>and</span> <span style=''>compare</span> <span style=' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12370025098601649)
# 	architecture (0.08461814270347795)
# 	representation (0.13445679455001794)
# 	processing (0.10577267837934744)
# 	segmentation (0.07171029042667623)
# 	different (0.26138400860523486)
# 	information (0.2509860164933668)
# 	detection (0.12441735389028326)
# 	convolutional (0.13087128002868412)
# 	recognition (0.13624955181068482)
#
# Some Statistics words are:
# 	numerical (0.10840377921432123)
# 	theoretical (0.14719045251118845)
# 	variables (0.1357533565390353)
# 	statistical (0.1516658378915962)
# 	estimation (0.17255096966683242)
# 	algorithm (0.3933366484336151)
# 	inference (0.19194430631526604)
# 	dimensional (0.18000994530084535)
# 	distribution (0.18299353555445053)
# 	regression (0.19045251118846346)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5fefe4f2-a10d-4abc-8d1a-9c7b0e0c5e62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5fefe4f2-a10d-4abc-8d1a-9c7b0e0c5e62")) {                    Plotly.newPlot(                        "5fefe4f2-a10d-4abc-8d1a-9c7b0e0c5e62",                        [{"x":["dimension","observations","algorithm","convergence","regularity","assumptions","complement","deterministic","objective","exponential","behaviour","asymptotically","according","observation","probability","decreases","approximate","demystifying","qualitative","generation","astonishing","excitement","discussion","worldwide","understood","structured","specially","agreement","additionally","bijective","partition","structure","alignment","arbitrarily","particular","significant","generalize","approximating","representing","positions","approximation","complexity","obtaining","polynomial","computing","screening","development","introduce","searching","efficient","advantage","predictive","demonstrate","corresponding","computational","efficiently","contribution","construct","guaranteed","representations","validated","limitations","important","stochastic","empirical","classifier","analytical","synthetic","consumption","quantized","opportunity","incurring","requirements","precision","understanding","precisions","hyperparameters","throughput","hyperparameter","classification","implementations","theoretic","hypothesis","dimensions","specifies","optimization","regression","hypotheses","generalizes","consistent","accommodate","constraint","multipliers","disparate","unexplored","dedicated","exploding","considering","subdivide","effective","decomposition","leverages","inherently","factorizations","experiments","properties","direction","fundamentally","computation","parallelization","independent","alternating","probabilistic","factorization","application","iterative","processing","constraints","multiplicative","incorporate","informatics","different","regularization","effectiveness","techniques","literature","nonlinear","sparseness","variation","separation","nonnegative","demonstrated","formulation","investigating","suggested","including","challenge","hyperspectral","estimation","framework","smoothness","extensions","functions","algorithms","representation","principal","dimensional","specified","component","comparison","distributions","posterior","continuous","prototype","inference","distribution","researchers","variational","efficiency","variables","maintains","expressive","parameters","hierarchical","introduction","algebraic","statistical","influential","unsupervised","principles","robustness","synthesized","estimator","covariance","asymptotic","sensitive","contaminated","generalized","quadratic","involving","influence","introduced","canonical","knowledge","characterize","correlation","intuitive","assumption","aggregated","instances","interested","exploratory","sentiment","comparisons","proportion","individual","proportions","differences","unrealistic","surprisingly","scenarios","recovering","unlabeled","geographical","information","estimating","propagation","exceeding","mimicking","prediction","supervised","interface","implemented","demonstrating","simulation","developed","emulation","extraction","automated","handwritten","implementation","interaction","formulate","essential","increasing","preservation","integration","foundations","character","similarity","sequences","transformation","evaluation","performance","outperform","recurrent","sentences","embeddings","convolutional","embedding","compositional","achieving","represented","architectures","structural","conventional","gaussianity","generating","strengths","identifies","algorithmic","relations","connection","typically","frameworks", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	precisions
# 	factorizations
# 	gaussianity
# 	intimately
# 	emphsparse
# 	chemoinformatics
# 	pharmacokinetic
# 	truncation
# 	differentiability
# 	diagonalization
# 	prewhitening
# 	interpolates
# 	preferably
# 	acyclicity
# 	hyperpriors
# 	presupposes
# 	acknowledging
# 	simplemkl
# 	submanifold
# 	variabilities
# Some words which never appear in Statistics papers:
# 	bijective
# 	discretizing
# 	locomotion
# 	entropies
# 	integrity
# 	globalization
# 	sustained
# 	bulgarian
# 	subnetwork
# 	activitynet
# 	ontological
# 	existential
# 	annihilation
# 	attentive
# 	specificities
# 	functioning
# 	plasticity
# 	unpredictable
# 	instruction
# 	paraphrase

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.078438615933998e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7858333333333334
